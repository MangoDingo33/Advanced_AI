# %%
import numpy as np
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.utils import to_categorical
from matplotlib import pyplot
import matplotlib.pyplot as plt
from keras.utils import plot_model
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# set seed to reproduce similar results
np.random.seed(0)
# Out:
# 2023-09-29 05:57:46.895265: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1]) 
                                                                                         if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

def get_human_dataset( ):
    
    # 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당.
    feature_name_df = pd.read_csv('/Users/mangodingo/Desktop/VS/Advanced_AI/0922/human_activity_ML/features.txt',sep='\s+',
                        header=None,names=['column_index','column_name'])
    
    # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame생성. 
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    # DataFrame에 피처명을 컬럼으로 부여하기 위해 리스트 객체로 다시 변환
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    # 학습 피처 데이터 셋과 테스트 피처 데이터을 DataFrame으로 로딩. 컬럼명은 feature_name 적용
    X_train = pd.read_csv('./human_activity_ML/train/X_train.txt',sep='\s+', names=feature_name )
    X_test = pd.read_csv('./human_activity_ML/test/X_test.txt',sep='\s+', names=feature_name)
    
    # 학습 레이블과 테스트 레이블 데이터을 DataFrame으로 로딩하고 컬럼명은 action으로 부여
    y_train = pd.read_csv('./human_activity_ML/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity_ML/test/y_test.txt',sep='\s+',header=None,names=['action'])
    
    # 로드된 학습/테스트용 DataFrame을 모두 반환 
    return X_train, X_test, y_train, y_test

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# 결정 트리에서 사용한 get_human_dataset( )을 이용해 학습/테스트용 DataFrame 반환
X_train, X_test, y_train, y_test = get_human_dataset()

print("## 학습 피처 데이터 정보 ##")
print(X_train.info())
# Out:
# ## 학습 피처 데이터 정보 ##
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 31.5 MB
# None

# %%
df_train = pd.concat([X_train, y_train],axis=1)
df_test = pd.concat([X_test, y_test],axis=1)
df = pd.concat([df_train, df_test],axis=0)

# %%
X_test
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# 1            -0.975415         -0.967458         -0.944958         -0.986799
# 2            -0.993819         -0.969926         -0.962748         -0.994403
# 3            -0.994743         -0.973268         -0.967091         -0.995274
# 4            -0.993852         -0.967445         -0.978295         -0.994111
# ...                ...               ...               ...               ...
# 2942         -0.287866         -0.140589         -0.215088         -0.356083
# 2943         -0.305388          0.028148         -0.196373         -0.373540
# 2944         -0.329638         -0.042143         -0.250181         -0.388017
# 2945         -0.323114         -0.229775         -0.207574         -0.392380
# 2946         -0.330046         -0.195253         -0.164339         -0.430974
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.925249         -0.674302         -0.894088  ...
# 1            -0.968401         -0.945823         -0.894088  ...
# 2            -0.970735         -0.963483         -0.939260  ...
# 3            -0.974471         -0.968897         -0.938610  ...
# 4            -0.965953         -0.977346         -0.938610  ...
# ...                ...               ...               ...  ...
# 2942         -0.148775         -0.232057          0.185361  ...
# 2943         -0.030036         -0.270237          0.185361  ...
# 2944         -0.133257         -0.347029          0.007471  ...
# 2945         -0.279610         -0.289477          0.007471  ...
# 2946         -0.218295         -0.229933         -0.111527  ...
#
#       fBodyBodyGyroJerkMag-meanFreq()  fBodyBodyGyroJerkMag-skewness()  \
# 0                            0.071645                        -0.330370
# 1                           -0.401189                        -0.121845
# 2                            0.062891                        -0.190422
# 3                            0.116695                        -0.344418
# 4                           -0.121711                        -0.534685
# ...                               ...                              ...
# 2942                         0.074472                        -0.376278
# 2943                         0.101859                        -0.320418
# 2944                        -0.066249                        -0.118854
# 2945                        -0.046467                        -0.205445
# 2946                        -0.010386                        -0.072237
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.705974                     0.006462
# 1                           -0.594944                    -0.083495
# 2                           -0.640736                    -0.034956
# 3                           -0.736124                    -0.017067
# 4                           -0.846595                    -0.002223
# ...                               ...                          ...
# 2942                        -0.750809                    -0.337422
# 2943                        -0.700274                    -0.736701
# 2944                        -0.467179                    -0.181560
# 2945                        -0.617737                     0.444558
# 2946                        -0.436940                     0.598808
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.162920                         -0.825886
# 1                                 0.017500                         -0.434375
# 2                                 0.202302                          0.064103
# 3                                 0.154438                          0.340134
# 4                                -0.040046                          0.736715
# ...                                    ...                               ...
# 2942                              0.346295                          0.884904
# 2943                             -0.372889                         -0.657421
# 2944                              0.088574                          0.696663
# 2945                             -0.819188                          0.929294
# 2946                             -0.287951                          0.876030
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                 0.271151             -0.720009
# 1                                 0.920593             -0.698091
# 2                                 0.145068             -0.702771
# 3                                 0.296407             -0.698954
# 4                                -0.118545             -0.692245
# ...                                    ...                   ...
# 2942                             -0.698885             -0.651732
# 2943                              0.322549             -0.655181
# 2944                              0.363139             -0.655357
# 2945                             -0.008398             -0.659719
# 2946                             -0.024965             -0.660080
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)
# 0                 0.276801             -0.057978
# 1                 0.281343             -0.083898
# 2                 0.280083             -0.079346
# 3                 0.284114             -0.077108
# 4                 0.290722             -0.073857
# ...                    ...                   ...
# 2942              0.274627              0.184784
# 2943              0.273578              0.182412
# 2944              0.274479              0.181184
# 2945              0.264782              0.187563
# 2946              0.263936              0.188103
#
# [2947 rows x 561 columns]

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7352, 561), (2947, 561), (7352, 1), (2947, 1))

# %%
cnn_model = Sequential()
cnn_model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(561, 1)))
cnn_model.add(MaxPooling1D())
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation='relu')) 
cnn_model.add(Dropout(0.5))# 은닉층 2
cnn_model.add(Dense(1,activation='softmax'))   # 클래스 수에 맞게 출력층 설정
cnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
from tensorflow import keras

checkpoint = ModelCheckpoint("best_cnn.h5", monitor="val_accuracy", verbose=1, save_best_only=True, mode="max")

# CNN 모델 학습
cnn_his = cnn_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), callbacks=checkpoint)

best_cnn = keras.models.load_model("best_cnn.h5")
# Out:
# Epoch 1/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 1: val_accuracy improved from -inf to 0.16831, saving model to best_cnn.h5
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 2/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 2: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 3/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 3: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 6s 52ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 4/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1669
# Epoch 4: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 5/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1669
# Epoch 5: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 44ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 6/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1674
# Epoch 6: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 7/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 7: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 8/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 8: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 42ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 9/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 9: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 48ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 10/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 10: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 6s 48ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 11/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 11: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 12/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 12: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 42ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 13/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 13: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 14/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 14: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 6s 52ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 15/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 15: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 6s 53ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 16/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1669
# Epoch 16: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 43ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 17/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 17: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 47ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 18/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 18: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 45ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 19/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 19: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 20/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 20: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 48ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 21/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 21: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 44ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 22/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 22: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 6s 52ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 23/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 23: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 45ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 24/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 24: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 40ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 25/50
# 115/115 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 25: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 26/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 26: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 45ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 27/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1665
# Epoch 27: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 47ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 28/50
# 114/115 [============================>.] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1668
# Epoch 28: val_accuracy did not improve from 0.16831
# 115/115 [==============================] - 5s 44ms/step - loss: 0.0000e+00 - accuracy: 0.1668 - val_loss: 0.0000e+00 - val_accuracy: 0.1683
# Epoch 29/50
#  30/115 [======>.......................] - ETA: 3s - loss: 0.0000e+00 - accuracy: 0.1714
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mangodingo/Desktop/VS/Advanced_AI/0922/HAR_DL.ipynb 셀 8 line 7
#       <a href='vscode-notebook-cell:/Users/mangodingo/Desktop/VS/Advanced_AI/0922/HAR_DL.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> checkpoint = ModelCheckpoint("best_cnn.h5", monitor="val_accuracy", verbose=1, save_best_only=True, mode="max")
#       <a href='vscode-notebook-cell:/Users/mangodingo/Desktop/VS/Advanced_AI/0922/HAR_DL.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> # CNN 모델 학습
# ----> <a href='vscode-notebook-cell:/Users/mangodingo/Desktop/VS/Advanced_AI/0922/HAR_DL.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> cnn_his = cnn_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), callbacks=checkpoint)
#       <a href='vscode-notebook-cell:/Users/mangodingo/Desktop/VS/Advanced_AI/0922/HAR_DL.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> best_cnn = keras.models.load_model("best_cnn.h5")
#
# File /opt/anaconda3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
